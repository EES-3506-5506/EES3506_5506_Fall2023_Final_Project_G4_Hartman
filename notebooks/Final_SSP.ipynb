# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import xarray as xr
import zarr  # to read in Zarr format
import gcsfs # to read google cloud data
import momlevel as ml
import cftime
import cmocean

# %%
xr.set_options(display_style='html')
# %matplotlib inline                           
# %config InlineBackend.figure_format='retina' 
plt.rcParams['figure.figsize'] = 12,6

# %%
google_cloud_cmip6 = pd.read_csv('https://storage.googleapis.com/cmip6/cmip6-zarr-consolidated-stores.csv')

# %%
SSP126_O2 = google_cloud_cmip6.query(
    "activity_id=='ScenarioMIP' & \
    table_id == 'Omon' & \
    variable_id == 'o2' & \
    experiment_id == 'ssp126' & \
    institution_id == 'NOAA-GFDL' &  \
    source_id == 'GFDL-ESM4' & \
    grid_label == 'gr' & \
    member_id == 'r1i1p1f1'"
)

# %%
SSP126_O2
#SSP 126 O2 data
# Out:
#        activity_id institution_id  source_id experiment_id member_id table_id  \
# 15681  ScenarioMIP      NOAA-GFDL  GFDL-ESM4        ssp126  r1i1p1f1     Omon
#
#       variable_id grid_label  \
# 15681          o2         gr
#
#                                                   zstore  dcpp_init_year  \
# 15681  gs://cmip6/CMIP6/ScenarioMIP/NOAA-GFDL/GFDL-ES...             NaN
#
#         version
# 15681  20180701

# %%
SSP245_O2 = google_cloud_cmip6.query(
    "activity_id=='ScenarioMIP' & \
    table_id == 'Omon' & \
    variable_id == 'o2' & \
    experiment_id == 'ssp245' & \
    institution_id == 'NOAA-GFDL' &  \
    source_id == 'GFDL-ESM4' & \
    grid_label == 'gr' & \
    member_id == 'r1i1p1f1'"
)

# %%
SSP245_O2
#SSP 245 O2
# Out:
#        activity_id institution_id  source_id experiment_id member_id table_id  \
# 15191  ScenarioMIP      NOAA-GFDL  GFDL-ESM4        ssp245  r1i1p1f1     Omon
#
#       variable_id grid_label  \
# 15191          o2         gr
#
#                                                   zstore  dcpp_init_year  \
# 15191  gs://cmip6/CMIP6/ScenarioMIP/NOAA-GFDL/GFDL-ES...             NaN
#
#         version
# 15191  20180701

# %%
SSP585_O2 = google_cloud_cmip6.query(
    "activity_id=='ScenarioMIP' & \
    table_id == 'Omon' & \
    variable_id == 'o2' & \
    experiment_id == 'ssp585' & \
    institution_id == 'NOAA-GFDL' &  \
    source_id == 'GFDL-ESM4' & \
    grid_label == 'gr' & \
    member_id == 'r1i1p1f1'"
)

# %%
SSP585_O2
#SSP 585 O2 data
# Out:
#        activity_id institution_id  source_id experiment_id member_id table_id  \
# 11670  ScenarioMIP      NOAA-GFDL  GFDL-ESM4        ssp585  r1i1p1f1     Omon
#
#       variable_id grid_label  \
# 11670          o2         gr
#
#                                                   zstore  dcpp_init_year  \
# 11670  gs://cmip6/CMIP6/ScenarioMIP/NOAA-GFDL/GFDL-ES...             NaN
#
#         version
# 11670  20180701

# %%
SSP126_O2SAT = google_cloud_cmip6.query(
    "activity_id=='ScenarioMIP' & \
    table_id == 'Omon' & \
    variable_id == 'o2sat' & \
    experiment_id == 'ssp126' & \
    institution_id == 'NOAA-GFDL' &  \
    source_id == 'GFDL-ESM4' & \
    grid_label == 'gr' & \
    member_id == 'r1i1p1f1'"
)

# %%
SSP126_O2SAT
# Out:
#        activity_id institution_id  source_id experiment_id member_id table_id  \
# 15679  ScenarioMIP      NOAA-GFDL  GFDL-ESM4        ssp126  r1i1p1f1     Omon
#
#       variable_id grid_label  \
# 15679       o2sat         gr
#
#                                                   zstore  dcpp_init_year  \
# 15679  gs://cmip6/CMIP6/ScenarioMIP/NOAA-GFDL/GFDL-ES...             NaN
#
#         version
# 15679  20180701

# %%
SSP245_O2SAT = google_cloud_cmip6.query(
    "activity_id=='ScenarioMIP' & \
    table_id == 'Omon' & \
    variable_id == 'o2sat' & \
    experiment_id == 'ssp245' & \
    institution_id == 'NOAA-GFDL' &  \
    source_id == 'GFDL-ESM4' & \
    grid_label == 'gr' & \
    member_id == 'r1i1p1f1'"
)

# %%
SSP245_O2SAT
# Out:
#        activity_id institution_id  source_id experiment_id member_id table_id  \
# 15189  ScenarioMIP      NOAA-GFDL  GFDL-ESM4        ssp245  r1i1p1f1     Omon
#
#       variable_id grid_label  \
# 15189       o2sat         gr
#
#                                                   zstore  dcpp_init_year  \
# 15189  gs://cmip6/CMIP6/ScenarioMIP/NOAA-GFDL/GFDL-ES...             NaN
#
#         version
# 15189  20180701

# %%
SSP585_O2SAT = google_cloud_cmip6.query(
    "activity_id=='ScenarioMIP' & \
    table_id == 'Omon' & \
    variable_id == 'o2sat' & \
    experiment_id == 'ssp585' & \
    institution_id == 'NOAA-GFDL' &  \
    source_id == 'GFDL-ESM4' & \
    grid_label == 'gr' & \
    member_id == 'r1i1p1f1'"
)

# %%
SSP585_O2SAT
# Out:
#        activity_id institution_id  source_id experiment_id member_id table_id  \
# 11655  ScenarioMIP      NOAA-GFDL  GFDL-ESM4        ssp585  r1i1p1f1     Omon
#
#       variable_id grid_label  \
# 11655       o2sat         gr
#
#                                                   zstore  dcpp_init_year  \
# 11655  gs://cmip6/CMIP6/ScenarioMIP/NOAA-GFDL/GFDL-ES...             NaN
#
#         version
# 11655  20180701
